# %% [markdown]
# ## Emotion Histogram by GCJ

# %% [markdown]
# Url used to extract the mating score material is as following: https://saifmohammad.com/WebPages/AffectIntensity.htm
#
# The latest version of Google Translate API is employed to facilitate the work.

# %%
import os
import re
import glob
import numpy as np
from collections import namedtuple, defaultdict
import numpy as np
import pandas as pd
import spacy
from spacy import displacy
import nltk
import en_core_web_sm
import fr_core_news_sm
import docx

import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  
nlp_fr = fr_core_news_sm.load()

# %%
Paths=[]


for file in glob.glob("./*.txt"):
    Paths.append(file)
    
print(Paths)
# Out:
# ['./277.txt', './278.txt', './71.txt', './527.txt', './118.txt', './93.txt', './90.txt', './747.txt', './454.txt', './116.txt', './524.txt', './67.txt', './7.txt', './175.txt', './739.txt', './15.txt', './72.txt', './257.txt', './696.txt', './51..txt', './57.txt', './283.txt', './531.txt', './105.txt', './210.txt', './505.txt', './446.txt', './148.txt', './821.txt', './32.txt', './128.txt', './107.txt', './793.txt', './66.txt', './159.txt', './157.txt', './732.txt', './674.txt', './534.txt', './88.txt', './76.txt', './28.txt', './59.txt', './133.txt', './99.txt', './207.txt', './78.txt', './182.txt', './185.txt', './225.txt', './45.txt', './523.txt']

# %%
l_corpus = []
#doc = pd.read_csv(path, delimiter='\t', encoding='cp1252')

# %%
All_words=[]
for path in Paths:
    #print(path)
    f=open(path,encoding='gbk')
    temp=[]
    line=f.readline()
    while line:
        temp+=line
        line=f.readline()
    f.close
    str=""
    temp=str.join(temp)
    All_words.append(temp)

# %%
print(np.array(All_words).shape)
# Out:
# (52,)

# %%
a=[]
a.append(Paths[0])
print(a)
# Out:
# ['./277.txt']

# %%
affects = pd.read_csv('../NRC-AffectIntensity-Lexicon-fr.txt', sep='\t')
affect_terms = set(affects['term'])

# %%
print(All_words[2])
# Out:
# ASSSI 71
#
# Nom de la personne qui retranscrit :
# Roussel Mathilde
# Date de l'entretien :
# 27 septembre 2008
# Date de la retranscription :
# 15 décembre 2009
#
# Sexe du patient :
# ? Homme                  ?   Femme
# Est-il /elle issu(e) d'une famille monoparentale :
# ? non	           ?   oui
#
#
#
# Le son était très mauvais !
#
# Alors pour commencer, j'aimerais que tu me présentes ta situation familiale durant l'enfance
# Ma situation familiale durant l'enfance, ben, moi pour commencer j'ai toujours été avec mes deux parents, j'ai eu une belle enfance
# Euh tes parents est-ce qu'ils sont divorcés ?
# Non jamais.
# Non, pis est-ce que t'as déménagé durant ton enfance ?
# Jamais.
# Non plus ? Ok. Pis est-ce que t'es le plus vieux ou le plus jeune ?
# Le plus vieux.
# Plus vieux. Pis quel genre de relation t'avais avec  ton frère quand t'étais petit ?
# Mon frère ?...quel genre de relation j'avais avec mon frère quand j'étais petit euh...  Mais pour être franc, j'avais jamais accepté, j'aurai toujours préféré être seul avec mes parents, mais maintenant ?a va mieux
# Ok. Pis quel genre de relation t'avais avec ta mère quand t'étais petit ?
# ... durant l'enfance, ben c'est s?r que je me méfiais un peu mai tu sais, fallait pas non plus parano?er, c'est pas parce que tu les connais pas que c'est des mauvaises personnes, mais j'essayais de me méfier
# Ouai, est-ce que t'as un exemple d'une fois où...
# Ben juste les personnes que tu croises dans la rue qui te demandent où est-ce qu'elle est cette rue là où c'est, cet endroit là c'est où.. ben je donne la réponse
# Pis dans les situations nouvelles ou inconnues comment tu réagissais ?
# Qu'est-ce que c'est que cette...
# Par exemple une situation nouvelle comme la première journée à l'école, quelque chose comme ?a
# Ben j'étais pas mal nerveux, mais c'était pas, c'était pas, ... c'était l'inco, c'est l'inconnu
# Ouai
# Mais non à part ?a ?a allait
# Est-ce que tu te souviens d'une situation nouvelle ?
# Premier jours à mon secondaire, quand tu connais pas personne
# Ok, pis est-ce que t'as déjà été en danger durant l'enfance ?
# Non pas vraiment.
# Non. Euh maintenant je te proposerais de parler des relations de couple que t'as connu.
# Relations de couple ok...
# Euh est-ce que tu pourrais me dire combien d'entre elles ont compté pour toi ?
# Combien d'entres elles ont compté pour moi ?
# Euh oui. Y'en a combien ?
# 3 ou 4
# Ok 3 ou 4.
# Approximativement parce que je me rappelle plus de laquelle
# Ok, ce que je te proposerai de parler de ces relations là ?
# ...
# Euh, est-ce que tu peux juste me donner les prénoms des partenaires de la plus ancienne à la plus récente pour qu'on se retrouve un peu ?
# Isabelle ... Stéphanie, c'est quoi déjà son nom... Isabelle... à la plus récente... j't'ai dis Stéphanie aussi ?
# Ouai
# Kim. C'est ?a.
# On va d'abord parler de ta relation avec Isabelle. Selon toi est-ce que l'un de vous deux était plus demandeur d'attention que l'autre ?
# Oui : elle.
# Elle ? Comment elle manifestait ces demandes là ?
# Comment elle manifestait ces demandes là... quand moi je parlais avec d'autre monde fallait tout le temps qu'elle m'arrête là, parce qu'elle était plus importante que les autres
# Ok. Pis toi comment tu réagissais à ces demandes là ?
# ... Des fois ?a m'énervait un peu mais je comprenais.
# Hum-hum
# ...
# Et durant cette relation est-ce qu'il t'est arrivé de traverser une épreuve difficile en dehors du couple ?
# En dehors du couple ?
# Ouai
# Non
# Non
# Pas plus que ?a. Non Non
# Pis est-ce que tu pourrais me raconter comment ?a se passait entre vous lors des conflits ?
# Lors des conflits bah, une fois
# Est-ce que tu te souviens d'un exemple de conflit ?
# ... le meilleur exemple que je peux te donner c'est quand elle a... c'est à cause de ?a aussi...
# Pis toi comment t'as réagis dans...?
# Je, j'ai, j'ai essayé de... tout quitter là, mais... c'est à cause de ?a qu'on a...
# Ok, et euh pendant cette relation est-ce qu'il t'est arrivé d'être séparé d'elle pour une raison quelconque ?
# Non pas vraiment, je la voyais presque chaque jours, j'allais à l'école avec.
# Pis quand t'étais malade comment tu te comportais vis-à-vis d'elle ?
# C'est jamais arrivé parce que ?a a pas duré, jamais arrivé.
# Pis pendant cette relation, est-ce qu'il t'est arrivé de te trouver dans une situation dangereuse ?
# Non
# Ah ben parce qu'à chaque fois ?a durait pas assez longtemps, c'était un mois ou deux, t'sais je tombais pas malade, j'avais pas de problème à part elle
# Ok, Pis est-ce que tu peux raconter comment ?a se passait lors des conflits ?
# Le seul con..., le seul conflit qu'on ait eu c'est parce, c'est quand on,... on se quittait
# Ok, pis durant la relation est-ce qu'il t'est arrivé d'être séparé d'elle
# Non, on allait à l'école chaque jour
# Ok, encore là t'as pas été malade, pis est-ce qu'il t'est arrivé de te trouver dans une situation dangereuse ?
# Non
# Non plus, pis pour quelles raison votre histoire s'est terminée ?
# Parce que ... elle a trouvé un autre copain
# Qu'est-ce que t'as ressenti ?
# Un peu de peine mais ... on s'habitue
# Pis elle comment elle s'est comportée, pendant la séparation ?
# Je dirais pas vraiment ce que je pense ... pis elle est partie... je pense pas ...
# Ok. Pis depuis est-ce que tes sentiments ont changé ?
# Oui
# Oui ?
# .... Elle non plus
# Euh pis maintenant dans ton histoire de vie en général est-ce qu'une évènement, un évènement marquant dont on n'a pas parlé ?
# Un évènement marquant ?
# Oui
# Tu peux répéter la question ?
# Dans ton histoire, en général, durant ta vie est-ce qu'il y a un évènement marquant qu'on n'aurait pas parlé ?
# Non
# Non
# Je crois pas
# Est-ce qu'il y a autre chose que t'aimerais rajouter ?
# Non
# Ben c'est terminé
# Terminé ?
# Ouai ! merci
#
# ASSSI 71		1/10

# %%
m=0
list_anger,list_fear,list_joy,list_sadness=[],[],[],[]

for person in All_words:
    utterance = nlp_fr(person)
    ut_affects = defaultdict(list)
    for word in utterance:
        term=word.lemma_.lower()
        if term in affect_terms:
            df_term = affects.loc[affects.loc[:, 'term'] == term, :]
            for j in df_term.index:
                ut_affects[df_term.loc[j, 'AffectDimension']].append((term, df_term.loc[j, 'score']))
    
    list_anger.append([Paths[m],ut_affects["anger"]])
    list_fear.append([Paths[m],ut_affects["fear"]])
    list_joy.append([Paths[m],ut_affects["joy"]])
    list_sadness.append([Paths[m],ut_affects["sadness"]])
    m=m+1
    /*.txt

# %%
print(np.array(list_anger).shape)
print(list_anger[0][1][1][1])
# Out:
# (52, 2)
# 0.75

# %%
score_joy,score_anger,score_fear,score_sadness=[],[],[],[]
temp_sum_joy,temp_sum_anger,temp_sum_fear,temp_sum_sadness=0,0,0,0
temp_ave_joy,temp_ave_anger,temp_ave_fear,temp_ave_sadness=0,0,0,0
for i in range(np.array(list_anger).shape[0]):
    for j in range(np.array(list_anger[i][1]).shape[0]):
        temp_sum_anger+=list_anger[i][1][j][1]
    temp_ave_anger=temp_sum_anger/j
    
    
    for j in range(np.array(list_joy[i][1]).shape[0]):
        temp_sum_joy+=list_joy[i][1][j][1]
    temp_ave_joy=temp_sum_joy/j
    
    
    for j in range(np.array(list_fear[i][1]).shape[0]):
        temp_sum_fear+=list_fear[i][1][j][1]
    temp_ave_fear=temp_sum_fear/j
    
    
    for j in range(np.array(list_sadness[i][1]).shape[0]):
        temp_sum_sadness+=list_sadness[i][1][j][1]
    temp_ave_sadness=temp_sum_sadness/j
    
    
    score_anger.append([Paths[i],round(temp_sum_anger,2),round(temp_ave_anger,2)])
    score_joy.append([Paths[i],round(temp_sum_joy,2),round(temp_ave_joy,2)])
    score_fear.append([Paths[i],round(temp_sum_fear,2),round(temp_ave_fear,2)])
    score_sadness.append([Paths[i],round(temp_sum_sadness,2),round(temp_ave_sadness,2)])  
    
    temp_sum_anger=0
    temp_sum_joy=0
    temp_sum_fear=0
    temp_sum_sadness=0

# %%
print(score_joy[1][1],score_anger[1][1],score_fear[1][1],score_sadness[1][1])
# Out:
# 114.36 42.79 54.48 67.94

# %%
X=['Joy','Anger','Fear','Sadness']
for i in range(np.array(score_anger).shape[0]):
    Y=[score_joy[i][1],score_anger[i][1],score_fear[i][1],score_sadness[i][1]]  
    fig = plt.figure()
    plt.bar(X,Y,0.4,color="green")
    plt.xlabel("Emotion")
    plt.ylabel("Sum_Score")
    plt.title("Emotion Bar"+Paths[i])

plt.show()
# Out:
# /home/rhett/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
from prettytable import *
table = PrettyTable(['Person_ID','Score_J','Score_A','Score_F','Score_S','Average_J','Average_A','Average_F','Average_S'])
for i in range(np.array(score_anger).shape[0]):
    table.add_row([Paths[i],score_joy[i][1],score_anger[i][1],score_fear[i][1],score_sadness[i][1],score_joy[i][2],score_anger[i][2],score_fear[i][2],score_sadness[i][2]])
print(table)
# Out:
# +-----------+---------+---------+---------+---------+-----------+-----------+-----------+-----------+
# | Person_ID | Score_J | Score_A | Score_F | Score_S | Average_J | Average_A | Average_F | Average_S |
# +-----------+---------+---------+---------+---------+-----------+-----------+-----------+-----------+
# | ./277.txt |  97.52  |  66.24  |  97.14  |  111.89 |    0.51   |    0.54   |    0.54   |    0.46   |
# | ./278.txt |  114.36 |  42.79  |  54.48  |  67.94  |    0.52   |    0.47   |    0.44   |    0.44   |
# |  ./71.txt |  74.22  |  26.02  |  37.79  |  53.92  |    0.52   |    0.46   |    0.47   |    0.42   |
# | ./527.txt |  77.38  |   62.3  |  64.61  |  71.57  |    0.51   |    0.51   |    0.48   |    0.46   |
# | ./118.txt |  93.75  |  68.77  |  86.62  |  114.21 |    0.48   |    0.5    |    0.48   |    0.42   |
# |  ./93.txt |  95.96  |  55.47  |  66.53  |  109.25 |    0.5    |    0.47   |    0.45   |    0.45   |
# |  ./90.txt |  252.86 |  72.35  |  84.41  |  106.95 |    0.59   |    0.51   |    0.48   |    0.47   |
# | ./747.txt |  146.53 |  39.88  |  81.37  |  114.97 |    0.53   |    0.47   |    0.48   |    0.49   |
# | ./454.txt |  88.92  |  23.52  |  49.58  |  52.68  |    0.56   |    0.49   |    0.51   |    0.41   |
# | ./116.txt |  190.74 |  118.28 |  114.78 |  176.33 |    0.53   |    0.52   |    0.43   |    0.45   |
# | ./157.txt |  189.18 |  130.97 |  171.58 |  178.1  |    0.51   |    0.52   |    0.48   |    0.45   |
# | ./732.txt |  155.79 |  48.11  |  68.86  |  108.89 |    0.53   |    0.51   |    0.49   |    0.43   |
# | ./674.txt |  35.67  |  21.76  |  37.21  |   34.9  |    0.49   |    0.45   |    0.45   |    0.44   |
# | ./534.txt |  170.3  |  81.67  |  111.12 |  181.05 |    0.51   |    0.45   |    0.47   |    0.45   |
# |  ./88.txt |  171.03 |  90.97  |  108.91 |  144.31 |    0.52   |    0.51   |    0.49   |    0.44   |
# |  ./76.txt |  161.05 |   45.0  |  54.63  |  67.22  |    0.55   |    0.45   |    0.45   |    0.42   |
# |  ./28.txt |  512.64 |  159.19 |  276.69 |  330.58 |    0.5    |    0.48   |    0.47   |    0.43   |
# |  ./59.txt |  148.27 |  54.12  |  99.39  |  112.14 |    0.54   |    0.47   |    0.45   |    0.46   |
# | ./133.txt |  295.44 |  235.33 |  287.94 |  346.97 |    0.52   |    0.52   |    0.52   |    0.45   |
# |  ./99.txt |  105.16 |  79.83  |  94.31  |  125.35 |    0.48   |    0.51   |    0.45   |    0.44   |
# | ./207.txt |   77.3  |  29.85  |  56.32  |  89.81  |    0.49   |    0.45   |    0.43   |    0.46   |
# |  ./78.txt |  120.23 |  41.39  |  55.81  |  80.35  |    0.48   |    0.47   |    0.43   |    0.46   |
# | ./182.txt |  154.55 |  85.25  |  134.21 |  147.21 |    0.51   |    0.51   |    0.53   |    0.47   |
# | ./185.txt |  161.15 |   85.7  |  104.59 |  137.76 |    0.52   |    0.53   |    0.51   |    0.43   |
# | ./225.txt |  103.75 |  47.02  |  73.89  |  102.98 |    0.51   |    0.49   |    0.48   |    0.5    |
# |  ./45.txt |  104.19 |  45.68  |   70.1  |   99.6  |    0.52   |    0.5    |    0.47   |    0.48   |
# | ./523.txt |  213.96 |  89.97  |  107.91 |  159.7  |    0.51   |    0.5    |    0.48   |    0.41   |
# +-----------+---------+---------+---------+---------+-----------+-----------+-----------+-----------+

# %% [markdown]
# ## AHP Analysis
# Analytic Hierarchy Process (AHP) is one of Multi Criteria decision making method that was originally developed by Prof. Thomas L. Saaty. In short, it is a method to derive ratio scales from paired comparisons.

# %% [markdown]
# Now let me explain what paired comparison is. It is always easier to explain by an example. Suppose we have two fruits Apple and Banana. I would like to ask you, which fruit you like better than the other and how much you like it in comparison with the other. Let us make a relative scale to measure how much you like the fruit on the left (Apple) compared to the fruit on the right (Banana).

# %% [markdown]
# ![title](AHP_Explaination.png)

# %% [markdown]
# If you like the apple better than banana, you thick a mark between number 1 and 9 on left side, while if you favor banana more than apple, then you mark on the right side.

# %% [markdown]
# When talking about the evaluation of the emotion, things are going the same way. The scores of each emotion, including being joy, anger sad and so on, are considered as the basic metric. To get the final score of pos or neg, we need several experts to add the contributation weight to compete the analysis net.

# %% [markdown]
# <img src="./AHP_Structure.png" width = "600" height = "400" alt="图片名称"
# align=center>
